# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## House Price Prediction Project
#
# This notebook performs comprehensive exploratory data analysis on the house price dataset.

# %% [markdown]
# ## 1. Load and Import Dependencies

# %% [markdown]
# ## 2. Load Raw Data

# %% [markdown]
# ## 3. Data Overview and Structure

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# ## 5. Data Quality Assessment

# %% [markdown]
# ## 6. Feature Engineering and Preprocessing

# %% [markdown]
# ## 7. Visualizations and Insights

# %% [markdown]
# ## 8. Save Processed Data
